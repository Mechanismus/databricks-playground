-- %%
SELECT "Hello from Databricks" AS message;

-- %%
CREATE OR REPLACE TABLE sales_demo AS
SELECT 'A100' AS AccountId, 'Acme Corp' AS AccountName, 120000 AS Revenue
UNION ALL
SELECT 'A200', 'Blue Sky Inc', 95000
UNION ALL
SELECT 'A300', 'FutureWorks', 135000;

-- %%
select * from sales_demo;
